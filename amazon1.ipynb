# %%
import pandas as pd

amazon_df = pd.read_csv('amazon.csv')
print(amazon_df.head())
# Out:
#                                           reviewText  Positive
# 0  This is a one of the best apps acording to a b...         1
# 1  This is a pretty good version of the game for ...         1
# 2  this is a really cool game. there are a bunch ...         1
# 3  This is a silly game and can be frustrating, b...         1
# 4  This is a terrific game on any pad. Hrs of fun...         1

# %%
amazon_df.shape
# Out:
# (20000, 2)

# %%
amazon_df.describe()
# Out:
#            Positive
# count  20000.000000
# mean       0.761650
# std        0.426085
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
amazon_df.info
# Out:
# <bound method DataFrame.info of                                               reviewText  Positive
# 0      This is a one of the best apps acording to a b...         1
# 1      This is a pretty good version of the game for ...         1
# 2      this is a really cool game. there are a bunch ...         1
# 3      This is a silly game and can be frustrating, b...         1
# 4      This is a terrific game on any pad. Hrs of fun...         1
# ...                                                  ...       ...
# 19995  this app is fricken stupid.it froze on the kin...         0
# 19996  Please add me!!!!! I need neighbors! Ginger101...         1
# 19997  love it!  this game. is awesome. wish it had m...         1
# 19998  I love love love this app on my side of fashio...         1
# 19999  This game is a rip off. Here is a list of thin...         0
#
# [20000 rows x 2 columns]>

# %%
# Find out if any columns has missing values
null_values = amazon_df.isnull().sum()
print(null_values)
# Out:
# reviewText    0
# Positive      0
# dtype: int64

# %%
# !pip install seaborn

# %%
# Visualize the dataset
import matplotlib.pyplot as plt
import seaborn as sns

# %% [raw]
# There are many visualization tools that can be used but it depends on your goal, first, lets use a cout plot to visualize the distribution of positive and negative feedback to see the number of people that gave which feedback. In simple terms, to understand the balance of positives and negatives. A bar chart or pie chart showing the counts or proportions of 0s and 1s can be used.
# Example tool: Seaborn's countplot or Matplot's bar can be used
# Below we use the countplot

# %%
sns.countplot(x='Positive', data=amazon_df)
plt.title('Class Distribution')
plt.show()

# %% [raw]
# Let me consider also using WordCloud that shows the mostly common used words in the reviws

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud

# Word cloud
positive_reviews = " ".join(amazon_df[amazon_df['Positive'] == 1]['reviewText'])
negative_reviews = " ".join(amazon_df[amazon_df['Positive'] == 0]['reviewText'])

positive_wc = WordCloud(width=800, height=400, background_color='white').generate(positive_reviews)
negative_wc = WordCloud(width=800, height=400, background_color='black').generate(negative_reviews)

# Display word clouds
plt.figure(figsize=(10, 5))
plt.imshow(positive_wc, interpolation='bilinear')
plt.title('Positive Reviews Word Cloud')
plt.axis('off')
plt.show()

plt.figure(figsize=(10, 5))
plt.imshow(negative_wc, interpolation='bilinear')
plt.title('Negative Reviews Word Cloud')
plt.axis('off')
plt.show()
